# %%
import pandas as pd
import os
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_excel('4_inn.xls')

# %%
df
# Out:
#       Unnamed: 0     #                                    name     reg_number  \
# 0              0     0         ЗАО «Власова, Макаров и Шашков»  1143692580560
# 1              1     1  РАО «Тимофеева, Алексеева и Кузнецова»  9342309660697
# 2              2     2                      РАО «Юдин-Ефимова»  1277485323451
# 3              3     3                   Доронин Инкорпорэйтед  7139161431511
# 4              4     4    Объединенная энергетическая компания  6114798049639
# ...          ...   ...                                     ...            ...
# 2105        2105  2105         ИП «Зайцев, Шубин и Дементьева»  6580539599719
# 2106        2106  2106                               Юдина Лтд  5012825137426
# 2107        2107  2107                        Антонова Лимитед  7659150538516
# 2108        2108  2108                    ООО «Хохлов Казаков»  9506828156265
# 2109        2109  2109                  ИП «Кабанов Ситникова»  5283860848622
#
# ...

# %%
inns = open('4_necessary_inn.txt').readlines()
for i in range(len(inns) - 1):
    inns[i] = inns[i][:-1]

# %%
inns
# Out:
# ['394609645484',
#  '281578625230',
#  '923769811917',
#  '998694734508',
#  '271011690615',
#  '924952812367',
#  '646685244561',
#  '581531230312',
#  '841967395801',
#  '962179889311',
#  '873191383820',
#  '590538076039',
#  '194319975048',
#  '614658394086',
#  '571270160555',
#  '609400911893',
#  '595260069852',
#  '706966142477',
#  '173050718969',
#  '968048428696',
#  '806967744814',
#  '575198252501',
#  '283081417246',
#  '663119569897',
#  '600958529354',
#  '280452832937',
#  '415557497037',
#  '195142638722',
#  '472181033836',
#  '722903871682',
#  '442387408954',
#  '196518820495',
#  '653798670054',
#  '126259856639',
#  '175482780898',
#  '192518356612',
#  '817648134701',
#  '321724220657',
#  '864970037680',
#  '822991191528',
#  '205472219644',
#  '532801459453',
#  '657038381012',
#  '197916669463',
#  '849814898285',
#  '617082656257',
#  '500480544925',
#  '765833725639',
#  '263518962896',
#  '415856290529',
#  '812729265571',
#  '688172366656',
# ...

# %%
df = df.query('head_inn in @inns')

# %%
df
# Out:
#       Unnamed: 0     #                                name     reg_number  \
# 47            47    47                      Пермэнергосбыт  6417532956774
# 76            76    76              ЗАО «Кабанова Ковалев»  9343329412518
# 77            77    77                             Неофарм  3813743111150
# 85            85    85                         Арконик СМЗ  7465966885549
# 90            90    90                     Фармперспектива  6205521489390
# ...          ...   ...                                 ...            ...
# 2059        2059  2059    ЗАО «Кабанова, Титов и Бирюкова»  4405157155853
# 2074        2074  2074  ООО «Фомин, Симонова и Никифорова»  9213736030860
# 2089        2089  2089                  НПО «Зимин Иванов»  6791957421599
# 2106        2106  2106                           Юдина Лтд  5012825137426
# 2108        2108  2108                ООО «Хохлов Казаков»  9506828156265
#
#                                                 address  \
# ...

# %%
df.to_csv('inns.csv')

# %%
df['income,RUB'].sum()
# Out:
# 6104522627393
