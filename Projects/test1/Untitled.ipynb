# %%
import pandas as pd
import numpy as np

# %%
df_sheet1 = pd.read_excel('ООО_Внимание_к_деталям.xlsx')
df_sheet2 = pd.read_excel('ООО_Внимание_к_деталям.xlsx', sheet_name='Выручка по обучающей выборке')

# %%
df_sheet1
# Out:
#       id точки                                              Адрес      Широта  \
# 0       8955.0   Оренбургская обл, Оренбург г, Шарлыкское ш, д...   55.118272
# 1      11007.0  Алтайский край, г. Барнаул, ул. Малахова, дом ...   83.696799
# 2      11366.0  Амурская область, Благовещенск, улица Мухина, 114  127.510357
# 3      11810.0  Архангельская обл, г. Архангельск , Троицкий п...   40.528249
# 4      15041.0  Архангельская обл, г. Архангельск, Троицкий пр...   40.526317
# ..         ...                                                ...         ...
# 241  2633929.0  Ямало-Ненецкий АО, г. Новый Уренгой, ул. Сибир...   76.631279
# 242  2633930.0  Ямало-Ненецкий АО, Ноябрьск г, Советская ул, д...   75.465427
# 243  2633935.0  Ярославская обл, г. Ярославль, ул. Победы, дом...   39.869236
# 244  2633946.0  Ярославская обл, г. Ярославль, ул. Свободы, до...   39.883707
# 245  2633948.0  Ярославская обл, Ярославский район, Телегински...   39.783545
#
# ...

# %%
df_sheet2
# Out:
#       id точки     2015-01-01     2015-02-01     2015-03-01     2015-04-01  \
# 0      11366.0  245709.342667  301024.685000  406199.782258  295602.853000
# 1      11810.0  270245.842066  297964.820199  406198.175918  232433.263996
# 2      15041.0  171972.976000  198141.440000  260215.741935  205316.010644
# 3      15775.0  409032.989736  468816.460949  582717.510920  442807.529886
# 4      16102.0  437693.191667  510077.198214  602107.617742  465779.798333
# ..         ...            ...            ...            ...            ...
# 150  2634000.0  341009.722000  413489.085501  518426.278387  376071.505667
# 151  2634008.0  270923.715000  404737.144643  470433.872222  401063.781000
# 152  2634011.0  378429.753517  350607.477988  482925.193552  367225.245935
# 153  2633936.0            NaN            NaN            NaN            NaN
# 154        NaN            NaN            NaN            NaN            NaN
#
#         2015-05-01     2015-06-01     2015-07-01     2015-08-01  \
# ...

# %%
df_sheet1.loc[df_sheet1['Формат магазина'] == 'Street', ['Формат магазина']] = 'Стрит'

# %%
df_sheet1.loc[df_sheet1['Формат магазина'] == 'Стрт', ['Формат магазина']] = 'Стрит'

# %%
df_sheet1.loc[df_sheet1['Формат магазина'] == 'Мини-ТЦ', ['Формат магазина']] = 'Мини ТЦ'

# %%
df_sheet1 = df_sheet1.rename(columns={'id точки': 'id'})
df_sheet2 = df_sheet2.rename(columns={'id точки': 'id'})

# %%
 df_sheet1[df_sheet1['Формат магазина'] == 'Стрит'].query('Выборка == "Тестовая"')
# Out:
#           id                                              Адрес     Широта  \
# 72   42059.0          г. Санкт-Петербург, Невский пр., дом № 27  30.327007
# 74   42072.0  г. Санкт-Петербург, Невский пр., дом № 90-92, ...  30.352412
# 119  42288.0  Краснодарский край, г. Сочи, ул. Навагинская, ...  39.723699
# 155  42466.0  Новгородская обл, г. Великий Новгород, ул. Газ...  31.271550
# 164  42499.0  Оренбургская обл, г. Оренбург, ул. Володарског...  55.102543
# 224  42792.0  Ставропольский край, Пятигорск, улица Крайнего...  43.070993
#
#        Долгота        Дата открытия Дата закрытия  Площадь магазина  \
# 72   59.935056  2005-03-03 00:00:00           NaT               234
# 74   59.932428  2003-09-16 00:00:00           NaT               136
# 119  43.587014  2002-04-06 00:00:00           NaT               172
# 155  58.524624  2011-04-14 00:00:00           NaT               375
# 164  51.768377  2007-02-11 00:00:00           NaT               272
# ...

# %%
df_sheet1[df_sheet1['Выборка'] == 'Обучающая'].shape
# Out:
# (156, 21)

# %%
list_id_ms = list(df_sheet1[df_sheet1['Формат магазина'] == 'Мини ТЦ']['id'].dropna())
list_id_ms
# Out:
# [18331.0,
#  18728.0,
#  41824.0,
#  41933.0,
#  42039.0,
#  42067.0,
#  42113.0,
#  42163.0,
#  42192.0,
#  42219.0,
#  42242.0,
#  42276.0,
#  42278.0,
#  42355.0,
#  42368.0,
#  42383.0,
#  42422.0,
#  42458.0,
#  42496.0,
#  42504.0,
#  42548.0,
#  42598.0,
#  42618.0,
#  42645.0,
#  42683.0,
#  42720.0,
#  42743.0,
#  42803.0,
#  42645.0,
#  2633930.0]

# %%
len(list_id_ms)
# Out:
# 30

# %%
col_list = [df_sheet2.columns[0]]
for i in list(df_sheet2.columns):
    if i[:4] == '2016':
        col_list.append(i)
col_list
# Out:
# ['id',
#  '2016-01-01',
#  '2016-02-01',
#  '2016-03-01',
#  '2016-04-01',
#  '2016-05-01',
#  '2016-06-01',
#  '2016-07-01',
#  '2016-08-01',
#  '2016-09-01',
#  '2016-10-01',
#  '2016-11-01',
#  '2016-12-01']

# %%
df_sheet2_2016 = df_sheet2[col_list]
df_sheet2_2016_new = df_sheet2_2016.query('id in @list_id_ms').fillna(0)
df_sheet2_2016_new
# Out:
#           id     2016-01-01     2016-02-01     2016-03-01     2016-04-01  \
# 11   18728.0  367034.640000  518191.520000  612575.473548  462814.800000
# 14   41824.0  288251.640000  380476.893103  409749.793548  335297.010000
# 23   41933.0   96125.460000  131703.051724  166441.238710  103033.830000
# 42   42067.0  618664.284420  778685.648276  948356.721290  610125.390000
# 56   42192.0  157156.285333  219535.906897  263464.079355  180751.274000
# 61   42219.0  165361.765333  183196.816166  234128.893793  181151.861333
# 66   42242.0  262235.282759  341500.413793  413340.774194  278217.413333
# 79   42355.0   79599.658667   99675.188966  129198.823226   83833.026207
# 80   42368.0  545935.139310  646203.233103  769325.914426  567838.250667
# 83   42383.0  252934.439333  315365.363793  396360.040323  268140.630333
# 84   42383.0  432084.774330  561409.609655  669310.098387  487761.416997
# 87   42422.0  221053.099355  236999.453793  294685.765161  186388.645333
# ...

# %%
df_sheet2_2016_new.dtypes
# Out:
# id            float64
# 2016-01-01    float64
# 2016-02-01    float64
# 2016-03-01    float64
# 2016-04-01    float64
# 2016-05-01    float64
# 2016-06-01    float64
# 2016-07-01    float64
# 2016-08-01    float64
# 2016-09-01    float64
# 2016-10-01    float64
# 2016-11-01    float64
# 2016-12-01     object
# dtype: object

# %%
df_sheet2_2016_new['2016-12-01'] = df_sheet2_2016_new['2016-12-01'].astype(str).str.replace(' ', '').astype(float)

# %%
df_sheet2_2016_new
# Out:
#           id     2016-01-01     2016-02-01     2016-03-01     2016-04-01  \
# 11   18728.0  367034.640000  518191.520000  612575.473548  462814.800000
# 14   41824.0  288251.640000  380476.893103  409749.793548  335297.010000
# 23   41933.0   96125.460000  131703.051724  166441.238710  103033.830000
# 42   42067.0  618664.284420  778685.648276  948356.721290  610125.390000
# 56   42192.0  157156.285333  219535.906897  263464.079355  180751.274000
# 61   42219.0  165361.765333  183196.816166  234128.893793  181151.861333
# 66   42242.0  262235.282759  341500.413793  413340.774194  278217.413333
# 79   42355.0   79599.658667   99675.188966  129198.823226   83833.026207
# 80   42368.0  545935.139310  646203.233103  769325.914426  567838.250667
# 83   42383.0  252934.439333  315365.363793  396360.040323  268140.630333
# 84   42383.0  432084.774330  561409.609655  669310.098387  487761.416997
# 87   42422.0  221053.099355  236999.453793  294685.765161  186388.645333
# ...

# %%
df_sheet2_2016_new.shape
# Out:
# (20, 13)

# %%
df_sheet2_2016_new.columns[12]
# Out:
# '2016-12-01'

# %%
mean = 0
for i in range(1,13):
    mean += df_sheet2_2016_new[df_sheet2_2016_new.columns[i]].mean()

# %%
mean
# Out:
# 3667471.993005723

# %%
df_sheet1[df_sheet1['Парковка'] == 'бесплатная парковка']['Парковка']
# Out:
# 0      бесплатная парковка
# 1      бесплатная парковка
# 2      бесплатная парковка
# 3      бесплатная парковка
# 4      бесплатная парковка
#               ...
# 238    бесплатная парковка
# 241    бесплатная парковка
# 242    бесплатная парковка
# 243    бесплатная парковка
# 245    бесплатная парковка
# Name: Парковка, Length: 156, dtype: object
